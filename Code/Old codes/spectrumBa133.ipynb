# %%
import matplotlib.pyplot as plt
from pylab import *
from io import StringIO

# %%
f = open('spectrumBa133.txt', 'r')
s = f.read()
s = loadtxt(StringIO(s))

# %%
numb_bins = 200

plt.figure(figsize=(15, 8))
plt.hist(s,bins=numb_bins,color='r')
#plt.ylim(0,800)
plt.show()
